# %%
import numpy as np
import matplotlib.pyplot as plt

t= [69.8884, 72.89, 54.5455, 72.886, 75.18, 62.52]
t = np.array(t)

a = [61.00, 65.50, 47.3642, 68.52, 70.20, 50.72]

# %%
# Train TR2 Test TS1
# blue solid line
plt.xlabel('Domain Adaptation Techniques')
plt.ylabel('Accuracies')
plt.plot(a, 'bD-')

# %%
plt.ylabel('Accuracies')
X_label = np.array([1, 2, 3, 4, 5, 6])

import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
line1, =plt.plot(X_label, t, 'r^--', label='Train TR1 Test TS2')
line2, =plt.plot(X_label, a, 'bD-', label='Train TR2 Test TS1')
#line3, =plt.plot([],label='1. TCA')
#line4, =plt.plot([],label='1. GFK')
#line5, =plt.plot([],label='1. CORAL')
#line6, =plt.plot([],label='1. SA')
#line7, =plt.plot([],label='1. STK')
#line8, =plt.plot([],label='1. BDA')

#first =plt.legend(handles=[line3,line4,line5,line6,line7,line8],bbox_to_anchor
 #          =(1.05,1),loc=2)
#ax = plt.gca().add_artist(first)

plt.legend()
plt.savefig('/home/aniruddha/deep-learning-projects/Siamese_Networks/finalfigs/5.png')

# %%
#Train TR1 Test TS2
# coral+contrastive
#red dotted line Training Accuracy
#blue solid line for test accuracy
X_train = np.array([79.47, 79.47, 83.49, 85.91, 88.41])
dim = np.array([5, 10, 16, 32, 64])
X_test = np.array([71.45, 69.74, 74.96, 76.08, 72.25])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
plt.plot(dim, X_train, 'r^--',dim, X_test, 'bD-')

# %%
#Train TR1 Test TS2
# log-coral+contrastive
#red dotted line Training Accuracy
#blue solid line for test accuracy
X_train = np.array([79.15, 71.18, 83.25, 83.49, 81.88])
dim = np.array([5, 10, 16, 32, 64])
X_test = np.array([66.51, 64.75, 70.02, 76.24, 70.65])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
plt.plot(dim, X_train, 'r^--',dim, X_test, 'bD-')

# %%
#Train TR2 Test TS1
#coral+contrastive
#red dotted line Training Accuracy
#blue solid line for test accuracy
X_train = np.array([85.77, 84.40, 85.62, 90.54, 92.18])
dim = np.array([5, 10, 16, 32, 64])
X_test = np.array([63.58, 62.38, 60.54, 69.73, 68.77])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
plt.plot(dim, X_train, 'r^--',dim, X_test, 'bD-')

# %%
#Train TR2 Test TS1
#log-coral+contrastive
#red dotted line Training Accuracy
#blue solid line for test accuracy
X_train = np.array([79.21, 86.38, 88.13, 90.27, 89.55])
dim = np.array([5, 10, 16, 32, 64])
X_test = np.array([60.54, 67.09, 65.02, 71.09, 70.13])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
plt.plot(dim, X_train, 'r^--',dim, X_test, 'bD-')

# %%
# Train TR1 Test TS2
# logcoral vs coral
# red dotted for logcoral
# blue solid for coral
X_c = np.array([71.45, 69.74, 74.96, 76.08, 72.25])
dim = np.array([5, 10, 16, 32, 64])
X_lc = np.array([66.51, 64.75, 70.02, 76.24, 70.65])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot(dim, X_lc, 'r^--', label='Test TS2 w/ LogCoral+Contrastive Loss')
line2, = plt.plot(dim, X_c, 'bD-', label='Test TS2 w/ Coral+Contrastive Loss')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=1)})
plt.savefig('/home/aniruddha/deep-learning-projects/Siamese_Networks/finalfigs/1.png')

# %%
# Train TR2 Test TS1
# logcoral vs coral
# red dotted for logcoral
# blue solid for coral
X_c = np.array([63.58, 62.38, 60.54, 69.73, 68.77])
dim = np.array([5, 10, 16, 32, 64])
X_lc = np.array([60.54, 67.09, 65.02, 71.09, 70.13])
plt.xlabel('Manifold output dimension')
plt.ylabel('Accuracies')
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot(dim, X_lc, 'r^--', label='Test TS1 w/ LogCoral+Contrastive Loss')
line2, = plt.plot(dim, X_c, 'bD-', label='Test TS1 w/ Coral+Contrastive Loss')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=1)})
plt.savefig('/home/aniruddha/deep-learning-projects/Siamese_Networks/finalfigs/2.png')

# %%
# Train TR2 Test TS1
# coral
# red dotted for train loss(contrastive)
# green dotted for validation(contrastive)
# blue solid for train loss(coral)
#
Tr_con = np.array([0.2864, 0.1593, 0.1102, 0.0848, 0.0790, 0.0771, 0.0763, 0.0755, 0.0745, 
                  0.0737, 0.0727, 0.0722, 0.0717, 0.0708, 0.0702, 0.0698, 0.0692, 0.0687,
                   0.0686, 0.0670, 0.0666, 0.0660, 0.0660, 0.0661, 0.0651, 0.0645, 0.0643, 0.0635, 0.0631, 0.0619, 
                  0.0615, 0.0617, 0.06605, 0.0601, 0.0604, 0.0599, 0.0596, 0.0589, 0.0591, 0.0588,
                   0.0587, 0.0583, 0.0580, 0.0574, 0.0570, 0.0575, 0.0575,  0.0580, 0.0564, 0.0567, 
                  ])
Te_con = np.array([0.1801, 0.1369, 0.1047, 0.0876, 0.0829, 0.0815, 0.0814, 0.0799, 0.0798,
                  0.0775, 0.0789, 0.0765, 0.0756, 0.0752, 0.0741, 0.0738, 0.0744, 0.0735, 
                  0.0753, 0.0724, 0.0715, 0.0724, 0.0697, 0.0705, 0.0692, 0.0703, 0.0686,
                  0.0700, 0.0670, 0.0660, 0.0677, 0.0673, 0.0663, 0.0661, 0.0650, 0.0648,
                  0.0664, 0.0650, 0.0664, 0.0665, 0.0648, 0.0645, 0.0631, 0.0641, 0.0642, 0.0638,
                  0.0653, 0.0623, 0.0625, 0.0624])
Tr_cor = np.array([3.4276, 41.7135, 45.8087, 17.2035, 10.6778, 5.3981, 4.9177, 9.5755, 
                  10.9557, 5.4487, 4.0503, 12.3835, 2.9439, 2.6655, 5.4903, 3.0618, 3.5031, 1.9901, 
                  3.7970, 6.2126, 4.8745, 1.9924, 1.9720, 2.0274, 4.8845, 2.7241, 2.1319,
                  1.7496, 3.5575, 1.6100, 3.9009, 2.1563, 2.0554, 2.8755, 1.2422, 2.9720, 2.4169, 
                  1.7261, 2.9677, 1.7649, 2.5059, 3.2430, 3.0275, 2.5374, 2.0215, 2.7783, 
                  1.7142, 2.7665, 1.6991, 1.4104])
Tr_cor = 0.01*Tr_cor
dim=[]
i=1
while i<=200:
    dim.append(i)
    i+=4
dim=np.array(dim)
plt.xlabel('Epochs')
plt.ylabel('Loss')
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot(dim, Tr_con, 'r-', label='Contrastive Loss')
line2, = plt.plot(dim, Tr_cor, 'b-', label='0.01*Coral Loss')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=1)})
#plt.plot(dim,Tr_con, 'r-', dim, Tr_cor, 'b-')
print(Tr_con.shape)
print(Te_con.shape)
plt.savefig('/home/aniruddha/deep-learning-projects/Siamese_Networks/finalfigs/3.png')
# Out:
# (50,)
# (50,)

# %%
# Train TR2 Test TS1
# coral
# red dotted for train loss(contrastive)
# green dotted for validation(contrastive)
# blue solid for train loss(logcoral)
Tr_con = np.array([0.2830, 0.1610, 0.1196, 0.0889, 0.0819, 0.0808, 0.0795, 
                   0.0789, 0.0788, 0.0775, 0.0771, 0.0769, 0.0765, 0.0758, 0.0750, 
                   0.0751, 0.0746, 0.0744, 0.0748, 0.0743, 0.0736, 0.0728, 0.0728, 0.0728, 
                   0.0717, 0.0710, 0.0709, 0.0700, 0.0699, 0.0683, 0.0655, 0.0649, 0.0642, 
                   0.0627, 0.0608, 0.0607, 0.0598, 0.0592, 0.0589, 0.0587, 0.0580, 0.0572, 
                   0.0575, 0.0574, 0.0564, 0.0552, 0.0553, 0.0548, 0.0550, 0.0544
                  ])
Te_con = np.array([0.1836, 0.1460, 0.1059, 0.0886, 0.0830, 0.0823, 0.0802, 0.0793,
                  0.0777, 0.0779, 0.0764, 0.0764, 0.0759, 0.0743, 0.0737, 0.0723, 
                  0.0736, 0.0731, 0.0728, 0.0715, 0.0716, 0.0715, 0.0703, 0.0689, 0.0693, 0.0682,
                  0.0659, 0.0662, 0.0648, 0.0632, 0.0635, 0.0641, 0.0605, 0.0592, 0.0588, 0.0584,
                  0.0573, 0.0573, 0.0565, 0.0554, 0.0561, 0.0558, 0.0554, 0.0539, 0.0538, 0.0540, 
                  0.0538, 0.0523, 0.0527, 0.0533,])

Tr_lcor = np.array([0.0035, 0.0038, 0.0041, 0.0037, 0.0056, 0.0034, 0.0039, 0.0036,
                   0.0018, 0.0011, 0.0022, 8.0423e-4, 0.0016, 7.7568e-4, 6.4427e-4,
                   7.5109e-4, 7.2776e-4, 3.7297e-4, 4.0011e-4, 2.6841e-4, 
                   2.5142e-4, 2.8694e-4, 1.7575e-4, 2.4295e-4, 4.6188e-4, 3.6755e-4,
                   4.0096e-4, 3.3390e-4, 2.6404e-4, 2.4178e-4, 2.3714e-4, 1.8385e-4, 
                   1.6635e-4, 3.5314e-4, 2.4514e-4, 2.1258e-4, 2.9800e-4, 2.5921e-4,
                   2.4799e-4, 3.0895e-4, 4.1696e-4, 2.4436e-4, 2.2368e-4, 2.7091e-4, 
                   2.4910e-4, 1.9278e-4, 2.7567e-4, 2.1318e-4, 1.2516e-4, 1.8951e-4])
Tr_lcor = 100*Tr_lcor
print(Tr_con.shape)
print(Tr_lcor.shape)
dim=[]
i=1
while i<=200:
    dim.append(i)
    i+=4
dim=np.array(dim)
plt.xlabel('Epochs')
plt.ylabel('Loss')
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot(dim, Tr_con, 'r-', label='Contrastive Loss')
line2, = plt.plot(dim, Tr_lcor, 'b-', label='100*LogCoral Loss')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=1)})
print(Tr_con.shape)
print(Te_con.shape)
print(Tr_lcor.shape)
plt.savefig('/home/aniruddha/deep-learning-projects/Siamese_Networks/finalfigs/4.png')
# Out:
# (50,)
# (50,)
# (50,)
# (50,)
# (50,)
